# %% [markdown]
# ### JSON Flattener - Pandas

# %%
import pandas as pd
api_response = [
    {"id": 101, "metrics": {"clicks": 50, "spend": 10.5}},
    {"id": 102, "metrics": {"clicks": 20, "spend": 5.0}},
    {"id": 103, "metrics": None}
]

df = pd.json_normalize(api_response)
print(df.head())
# Out:
#     id  metrics.clicks  metrics.spend  metrics
# 0  101            50.0           10.5      NaN
# 1  102            20.0            5.0      NaN
# 2  103             NaN            NaN      NaN
